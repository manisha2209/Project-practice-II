# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df=df[['Country', 'Region', 'Happiness Rank','Standard Error', 'Economy (GDP per Capita)', 'Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual', 'Happiness Score']]

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Standard Error  \
# 0  Switzerland  Western Europe               1         0.03411
# 1      Iceland  Western Europe               2         0.04884
# 2      Denmark  Western Europe               3         0.03328
# 3       Norway  Western Europe               4         0.03880
# 4       Canada   North America               5         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  \
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# 3                        0.36503     0.34699            2.46531
# 4                        0.32957     0.45811            2.45176
#
#    Happiness Score
# 0            7.587
# 1            7.561
# 2            7.527
# 3            7.522
# 4            7.427

# %%
df.describe()
# Out:
#        Happiness Rank  Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000      158.000000                158.000000  158.000000
# mean        79.493671        0.047885                  0.846137    0.991046
# std         45.754363        0.017146                  0.403121    0.272369
# min          1.000000        0.018480                  0.000000    0.000000
# 25%         40.250000        0.037268                  0.545808    0.856823
# 50%         79.500000        0.043940                  0.910245    1.029510
# 75%        118.750000        0.052300                  1.158448    1.214405
# max        158.000000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual  Happiness Score
# count  158.000000         158.000000       158.000000
# mean     0.237296           2.098977         5.375734
# std      0.126685           0.553550         1.145010
# min      0.000000           0.328580         2.839000
# 25%      0.150553           1.759410         4.526000
# 50%      0.216130           2.095415         5.232500
# 75%      0.309883           2.462415         6.243750
# max      0.795880           3.602140         7.587000

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# Happiness Score                  0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# There is no null value in the dataset.

# %%
sns.distplot(df['Family'])                                                 #### data visualisation
# Out:
# <Axes: xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Happiness Rank'])
# Out:
# <Axes: xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <Axes: xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <Axes: xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'])                    ##### normalized data
# Out:
# <Axes: xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
df.plot(kind='kde',subplots=True,layout=(5,2),figsize=(20,40))
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %%
df.plot(kind='box',subplots=True,layout=(6,2),figsize=(20,40))
# Out:
# Happiness Rank                       Axes(0.125,0.77;0.352273x0.11)
# Standard Error                    Axes(0.547727,0.77;0.352273x0.11)
# Economy (GDP per Capita)            Axes(0.125,0.638;0.352273x0.11)
# Family                           Axes(0.547727,0.638;0.352273x0.11)
# Health (Life Expectancy)            Axes(0.125,0.506;0.352273x0.11)
# Freedom                          Axes(0.547727,0.506;0.352273x0.11)
# Trust (Government Corruption)       Axes(0.125,0.374;0.352273x0.11)
# Generosity                       Axes(0.547727,0.374;0.352273x0.11)
# Dystopia Residual                   Axes(0.125,0.242;0.352273x0.11)
# Happiness Score                  Axes(0.547727,0.242;0.352273x0.11)
# dtype: object

# %%
sns.pairplot(df)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Happiness Score                  float64
# dtype: object

# %%
df.drop(['Happiness Rank','Country','Region'],axis=1,inplace=True)
df.head()
# Out:
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual  Happiness Score
# 0     0.29678            2.51738            7.587
# 1     0.43630            2.70201            7.561
# 2     0.34139            2.49204            7.527
# 3     0.34699            2.46531            7.522
# 4     0.45811            2.45176            7.427

# %%
from scipy.stats import zscore                                      #### removing outliers
z=np.abs(zscore(df))
z
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0          0.805926                  1.369621  1.320281
# 1          0.055889                  1.135226  1.514458
# 2          0.854487                  1.192861  1.361054
# 3          0.531526                  1.525130  1.251922
# 4          0.722845                  1.194876  1.221204
# ..              ...                       ...       ...
# 153        0.774917                  1.552987  0.800520
# 154        0.662582                  1.392303  2.346860
# 155        0.132534                  0.455245  1.901086
# 156        2.263962                  2.067566  2.118467
# 157        1.134182                  1.586334  3.134725
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    1.263408  1.577438                       2.309652
# 1                    1.289434  1.332456                       0.016480
# 2                    0.992229  1.469659                       2.842774
# 3                    1.035145  1.605131                       1.852081
# 4                    1.118054  1.360416                       1.555725
# ..                        ...       ...                            ...
# 153                  0.818610  1.087740                       3.413922
# 154                  1.263362  0.372033                       0.529210
# 155                  0.372199  1.809238                       0.381419
# 156                  1.649648  2.064472                       0.357715
# 157                  1.404129  0.426621                       0.301803
#
#      Generosity  Dystopia Residual  Happiness Score
# 0      0.471040           0.758258         1.937360
# 1      1.575856           1.092857         1.914581
# 2      0.824293           0.712335         1.884792
# 3      0.868638           0.663893         1.880411
# 4      1.748563           0.639337         1.797179
# ..          ...                ...              ...
# 153    0.087228           2.588925         1.674055
# 154    0.433117           0.843967         1.783571
# 155    1.856891           3.208430         2.076199
# 156    0.316950           0.481985         2.164688
# 157    0.558153           0.963612         2.222513
#
# [158 rows x 9 columns]

# %%
threshold=3
print(np.where(z>3))
df_new=df[(z<3).all(axis=1)]
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([5, 0, 0, 0, 6, 2, 5, 7, 2], dtype=int64))

# %%
df=df_new
df.shape
# Out:
# (149, 9)

# %%
# dividing the columns for machine learning


x=df.iloc[:,:-1]

y=df.iloc[:,-1]

# %%
# dividing the columns for machine learning

#independent column
x=df.iloc[:,:-1]
#target value
y=df.iloc[:,-1]
# transforming the data

from sklearn.preprocessing import power_transform
x=power_transform(x)
x
# Out:
# array([[-0.95033703,  1.49245411,  1.65888016, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [ 0.37856182,  1.19406711,  2.00912496, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [-1.04140135,  1.26661161,  1.73078528, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [-1.32081011, -1.36521585, -2.08738878, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [-0.69272644, -1.43304072, -2.01044293, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 2.17876604, -1.93874732, -1.90641014, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %%
# scaling the data

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.95033703,  1.49245411,  1.65888016, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [ 0.37856182,  1.19406711,  2.00912496, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [-1.04140135,  1.26661161,  1.73078528, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [-1.32081011, -1.36521585, -2.08738878, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [-0.69272644, -1.43304072, -2.01044293, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 2.17876604, -1.93874732, -1.90641014, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
# defining the different models

lg=LinearRegression()
rdr=RandomForestRegressor()
svr=SVR()
dtr=DecisionTreeRegressor()
knr=KNeighborsRegressor()

# %%
# train the model at different random states and getting the accuracy score for each rangom state for every machine learning model

model=[lg,rdr,svr,dtr,knr]
for i in range(40,60):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.30)
    for j in model:
        j.fit(x_train,y_train)
        pred_train=j.predict(x_train)
        pred_test=j.predict(x_test)
        print('Accuracy score at ',i , 'random state',j,':',j.score(x_train,y_train)*100)
        print('\n')
# Out:
# Accuracy score at  40 random state LinearRegression() : 99.4046026873666
#
#
# Accuracy score at  40 random state RandomForestRegressor() : 98.77192795888364
#
#
# Accuracy score at  40 random state SVR() : 98.43038006172999
#
#
# Accuracy score at  40 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  40 random state KNeighborsRegressor() : 93.43573573078007
#
#
# Accuracy score at  41 random state LinearRegression() : 99.51921678136677
#
#
# Accuracy score at  41 random state RandomForestRegressor() : 98.5646956333147
#
#
# Accuracy score at  41 random state SVR() : 98.58151697319566
#
#
# Accuracy score at  41 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  41 random state KNeighborsRegressor() : 93.07688117198877
#
#
# Accuracy score at  42 random state LinearRegression() : 99.33355590443901
#
#
# Accuracy score at  42 random state RandomForestRegressor() : 98.27081005144254
#
#
# Accuracy score at  42 random state SVR() : 98.56881861698098
#
#
# Accuracy score at  42 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  42 random state KNeighborsRegressor() : 92.02910750766485
#
#
# Accuracy score at  43 random state LinearRegression() : 99.39384342989784
#
#
# Accuracy score at  43 random state RandomForestRegressor() : 98.55364362777841
#
#
# Accuracy score at  43 random state SVR() : 98.67429924685337
#
#
# Accuracy score at  43 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  43 random state KNeighborsRegressor() : 92.83298189221378
#
#
# Accuracy score at  44 random state LinearRegression() : 99.5035526175871
#
#
# Accuracy score at  44 random state RandomForestRegressor() : 98.65644633851228
#
#
# Accuracy score at  44 random state SVR() : 98.90736425026478
#
#
# Accuracy score at  44 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  44 random state KNeighborsRegressor() : 93.18052195519869
#
#
# Accuracy score at  45 random state LinearRegression() : 99.45529874035667
#
#
# Accuracy score at  45 random state RandomForestRegressor() : 98.69721753226436
#
#
# Accuracy score at  45 random state SVR() : 98.51956790692942
#
#
# Accuracy score at  45 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  45 random state KNeighborsRegressor() : 93.71532471762129
#
#
# Accuracy score at  46 random state LinearRegression() : 99.47437838251349
#
#
# Accuracy score at  46 random state RandomForestRegressor() : 98.542525176833
#
#
# Accuracy score at  46 random state SVR() : 98.55172779587784
#
#
# Accuracy score at  46 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  46 random state KNeighborsRegressor() : 93.62901327034176
#
#
# Accuracy score at  47 random state LinearRegression() : 99.43157653649874
#
#
# Accuracy score at  47 random state RandomForestRegressor() : 98.34095364897543
#
#
# Accuracy score at  47 random state SVR() : 98.93687803501084
#
#
# Accuracy score at  47 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  47 random state KNeighborsRegressor() : 92.36010476948096
#
#
# Accuracy score at  48 random state LinearRegression() : 99.57662413797624
#
#
# Accuracy score at  48 random state RandomForestRegressor() : 98.39277484558195
#
#
# Accuracy score at  48 random state SVR() : 99.02061895143498
#
#
# Accuracy score at  48 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  48 random state KNeighborsRegressor() : 94.19988296548043
#
#
# Accuracy score at  49 random state LinearRegression() : 99.3703864072087
#
#
# Accuracy score at  49 random state RandomForestRegressor() : 98.69966949664891
#
#
# Accuracy score at  49 random state SVR() : 98.61098625205092
#
#
# Accuracy score at  49 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  49 random state KNeighborsRegressor() : 92.41185521760407
#
#
# Accuracy score at  50 random state LinearRegression() : 99.41093227373598
#
#
# Accuracy score at  50 random state RandomForestRegressor() : 98.71214067403733
#
#
# Accuracy score at  50 random state SVR() : 98.64523852921914
#
#
# Accuracy score at  50 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  50 random state KNeighborsRegressor() : 93.80054526037863
#
#
# Accuracy score at  51 random state LinearRegression() : 99.48696070608564
#
#
# Accuracy score at  51 random state RandomForestRegressor() : 98.5191185091297
#
#
# Accuracy score at  51 random state SVR() : 98.40353124475834
#
#
# Accuracy score at  51 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  51 random state KNeighborsRegressor() : 92.75368712463826
#
#
# Accuracy score at  52 random state LinearRegression() : 99.49886979673263
#
#
# Accuracy score at  52 random state RandomForestRegressor() : 98.5314653145013
#
#
# Accuracy score at  52 random state SVR() : 98.57565082906461
#
#
# Accuracy score at  52 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  52 random state KNeighborsRegressor() : 93.19871203728074
#
#
# Accuracy score at  53 random state LinearRegression() : 99.47736748897186
#
#
# Accuracy score at  53 random state RandomForestRegressor() : 98.70514041980154
#
#
# Accuracy score at  53 random state SVR() : 98.50353029763977
#
#
# Accuracy score at  53 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  53 random state KNeighborsRegressor() : 92.47963678172711
#
#
# Accuracy score at  54 random state LinearRegression() : 99.52282764522073
#
#
# Accuracy score at  54 random state RandomForestRegressor() : 98.80690288620053
#
#
# Accuracy score at  54 random state SVR() : 98.99294603024678
#
#
# Accuracy score at  54 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  54 random state KNeighborsRegressor() : 95.1536088762315
#
#
# Accuracy score at  55 random state LinearRegression() : 99.5417974557022
#
#
# Accuracy score at  55 random state RandomForestRegressor() : 98.29023903655992
#
#
# Accuracy score at  55 random state SVR() : 99.01315085379265
#
#
# Accuracy score at  55 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  55 random state KNeighborsRegressor() : 92.46047658541639
#
#
# Accuracy score at  56 random state LinearRegression() : 99.3618068248088
#
#
# Accuracy score at  56 random state RandomForestRegressor() : 98.61062288526703
#
#
# Accuracy score at  56 random state SVR() : 98.403970119787
#
#
# Accuracy score at  56 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  56 random state KNeighborsRegressor() : 93.2349247566554
#
#
# Accuracy score at  57 random state LinearRegression() : 99.41918557033947
#
#
# Accuracy score at  57 random state RandomForestRegressor() : 98.41963217209987
#
#
# Accuracy score at  57 random state SVR() : 98.412622276669
#
#
# Accuracy score at  57 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  57 random state KNeighborsRegressor() : 92.12466894631872
#
#
# Accuracy score at  58 random state LinearRegression() : 99.37864461302435
#
#
# Accuracy score at  58 random state RandomForestRegressor() : 98.46908735286954
#
#
# Accuracy score at  58 random state SVR() : 98.41028443962593
#
#
# Accuracy score at  58 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  58 random state KNeighborsRegressor() : 92.19638885810386
#
#
# Accuracy score at  59 random state LinearRegression() : 99.45070851732065
#
#
# Accuracy score at  59 random state RandomForestRegressor() : 98.45499076863248
#
#
# Accuracy score at  59 random state SVR() : 98.38144037799327
#
#
# Accuracy score at  59 random state DecisionTreeRegressor() : 100.0
#
#
# Accuracy score at  59 random state KNeighborsRegressor() : 92.60639929591316

# %%
#calculating the cross val score for each model at different cv

from sklearn.model_selection import cross_val_score
for i in range(2,7):
    for j in model:
        cr=cross_val_score(j,x,y,cv=i)
        cr_mean=cr.mean()
        print("at cv= ", i)
        print('cross val score = ',cr_mean*100)
        print('accuracy score of',j ,' = ',j.score(x_train,y_train)*100)
        print('\n')
# Out:
# at cv=  2
# cross val score =  84.96218971408204
# accuracy score of LinearRegression()  =  99.45070851732065
#
#
# at cv=  2
# cross val score =  -424.40938259214073
# accuracy score of RandomForestRegressor()  =  98.45499076863248
#
#
# at cv=  2
# cross val score =  -440.54532679879605
# accuracy score of SVR()  =  98.38144037799327
#
#
# at cv=  2
# cross val score =  -449.0878953824067
# accuracy score of DecisionTreeRegressor()  =  100.0
#
#
# at cv=  2
# cross val score =  -432.483097482309
# accuracy score of KNeighborsRegressor()  =  92.60639929591316
#
#
# at cv=  3
# cross val score =  88.48139146971018
# accuracy score of LinearRegression()  =  99.45070851732065
#
#
# at cv=  3
# cross val score =  -269.4305833141059
# accuracy score of RandomForestRegressor()  =  98.45499076863248
#
#
# at cv=  3
# cross val score =  -302.17110410974965
# accuracy score of SVR()  =  98.38144037799327
#
#
# at cv=  3
# cross val score =  -354.2184131073476
# accuracy score of DecisionTreeRegressor()  =  100.0
#
#
# at cv=  3
# cross val score =  -330.44219680325006
# accuracy score of KNeighborsRegressor()  =  92.60639929591316
#
#
# at cv=  4
# cross val score =  82.40004177926359
# accuracy score of LinearRegression()  =  99.45070851732065
#
#
# at cv=  4
# cross val score =  -441.7517187904769
# accuracy score of RandomForestRegressor()  =  98.45499076863248
#
#
# at cv=  4
# cross val score =  -310.8857729287286
# accuracy score of SVR()  =  98.38144037799327
#
#
# at cv=  4
# cross val score =  -953.4560330581994
# accuracy score of DecisionTreeRegressor()  =  100.0
#
#
# at cv=  4
# cross val score =  -441.53965624656496
# accuracy score of KNeighborsRegressor()  =  92.60639929591316
#
#
# at cv=  5
# cross val score =  81.09522873164187
# accuracy score of LinearRegression()  =  99.45070851732065
#
#
# at cv=  5
# cross val score =  -360.9467444721271
# accuracy score of RandomForestRegressor()  =  98.45499076863248
#
#
# at cv=  5
# cross val score =  -312.941259166631
# accuracy score of SVR()  =  98.38144037799327
#
#
# at cv=  5
# cross val score =  -803.1602472847577
# accuracy score of DecisionTreeRegressor()  =  100.0
#
#
# at cv=  5
# cross val score =  -530.9063553594314
# accuracy score of KNeighborsRegressor()  =  92.60639929591316
#
#
# at cv=  6
# cross val score =  74.123252877523
# accuracy score of LinearRegression()  =  99.45070851732065
#
#
# at cv=  6
# cross val score =  -436.58939753236734
# accuracy score of RandomForestRegressor()  =  98.45499076863248
#
#
# at cv=  6
# cross val score =  -248.819882291287
# accuracy score of SVR()  =  98.38144037799327
#
#
# at cv=  6
# cross val score =  -1081.9842736872076
# accuracy score of DecisionTreeRegressor()  =  100.0
#
#
# at cv=  6
# cross val score =  -549.0226599376001
# accuracy score of KNeighborsRegressor()  =  92.60639929591316

# %%
#calculating the r2 score for each model

from sklearn.metrics import r2_score
for i in model:
    print(i)
    print(r2_score(y_test,pred_test))
    print('\n')
# Out:
# LinearRegression()
# 0.8710909116406275
#
#
# RandomForestRegressor()
# 0.8710909116406275
#
#
# SVR()
# 0.8710909116406275
#
#
# DecisionTreeRegressor()
# 0.8710909116406275
#
#
# KNeighborsRegressor()
# 0.8710909116406275

# %%
# calculating the errors in different models

for i in model:
    print(i)
    print('mean absolut error: ',mean_absolute_error(y_test,pred_test))
    print('mean squared error: ',mean_squared_error(y_test,pred_test))
    print('root mean squared error: ',np.sqrt(mean_squared_error(y_test,pred_test)))
    print('\n')
# Out:
# LinearRegression()
# mean absolut error:  0.32363555555555557
# mean squared error:  0.17519568000000002
# root mean squared error:  0.418563830257704
#
#
# RandomForestRegressor()
# mean absolut error:  0.32363555555555557
# mean squared error:  0.17519568000000002
# root mean squared error:  0.418563830257704
#
#
# SVR()
# mean absolut error:  0.32363555555555557
# mean squared error:  0.17519568000000002
# root mean squared error:  0.418563830257704
#
#
# DecisionTreeRegressor()
# mean absolut error:  0.32363555555555557
# mean squared error:  0.17519568000000002
# root mean squared error:  0.418563830257704
#
#
# KNeighborsRegressor()
# mean absolut error:  0.32363555555555557
# mean squared error:  0.17519568000000002
# root mean squared error:  0.418563830257704

# %%
import numpy as np                                                                            #### conclusion
a=np.array(y_test)
pred=np.array(lg.predict(x_test))
hscore=pd.DataFrame({'Actual':a,'Predicted':pred})
hscore
# Out:
#     Actual  Predicted
# 0    6.575   6.705178
# 1    5.140   5.110040
# 2    4.839   4.872432
# 3    4.297   4.295198
# 4    5.129   5.101666
# 5    4.252   4.267714
# 6    3.904   3.892097
# 7    5.987   6.160929
# 8    3.587   3.642811
# 9    5.073   5.027985
# 10   4.550   4.541388
# 11   6.867   6.850564
# 12   3.681   3.775800
# 13   5.695   5.780248
# 14   6.477   6.448810
# 15   5.770   5.735807
# 16   5.194   5.322969
# 17   4.739   4.764352
# 18   5.716   5.633309
# 19   6.574   6.581910
# 20   4.642   4.627770
# 21   5.689   5.756795
# 22   5.889   5.793949
# 23   3.956   3.984143
# 24   4.959   4.962711
# 25   7.587   7.654294
# 26   5.890   5.816730
# 27   4.292   4.564220
# 28   3.995   4.051133
# 29   6.798   6.793589
# 30   5.948   6.075455
# 31   4.565   4.693311
# 32   4.885   4.871702
# 33   4.857   4.877097
# 34   3.667   3.770601
# 35   6.901   6.848917
# 36   6.485   6.481198
# 37   4.518   4.483653
# 38   3.845   3.952187
# 39   3.340   3.584512
# 40   3.575   3.829094
# 41   5.013   4.986271
# 42   7.561   7.749987
# 43   7.278   7.359348
# 44   3.656   3.869872
